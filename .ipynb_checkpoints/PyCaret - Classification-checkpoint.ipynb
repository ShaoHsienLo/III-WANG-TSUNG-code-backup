# %%
# install pycaret
# !pip3 install --user pycaret
# import sys
# !{sys.executable} -m pip install pycaret
import pandas as pd
import os
from sklearn.model_selection import train_test_split 
from pycaret.classification import *
import numpy as np

# %%
df_1_2 = pd.read_csv("./labeled-data/1st-2st-labeling/all-labeled-data.csv")
df_3 = pd.read_csv("./labeled-data/3st-labeling/all-labeled-data.csv")
data = pd.concat([df_1_2, df_3], ignore_index=True)

data = data.drop(columns=data.filter(regex="discharge.*").columns)
data = data.drop(columns=data.filter(regex=".*_count_nonzero").columns)
data = data.drop(columns=["original label"])

X = data.drop(columns=["final label"])
y = data["final label"]

# data = pd.read_csv("./input-data/input.csv")

# X = data.drop(columns=["label"])
# y = data["label"]

# %%
data.columns
# Out:
# Index(['ingot_mean', 'ingot_median', 'ingot_max', 'ingot_min', 'ingot_std',
#        'ingot_var', 'ingot_sum', 'ingot_skew', 'ingot_kurt', 'ingot_mode',
#        'ingot_ptp', 'ingot_iqr', 'ingot_sem', 'mould_mean', 'mould_median',
#        'mould_max', 'mould_min', 'mould_std', 'mould_var', 'mould_sum',
#        'mould_skew', 'mould_kurt', 'mould_mode', 'mould_ptp', 'mould_iqr',
#        'mould_sem', 'oil_pressure_mean', 'oil_pressure_median',
#        'oil_pressure_max', 'oil_pressure_min', 'oil_pressure_std',
#        'oil_pressure_var', 'oil_pressure_sum', 'oil_pressure_skew',
#        'oil_pressure_kurt', 'oil_pressure_mode', 'oil_pressure_ptp',
#        'oil_pressure_iqr', 'oil_pressure_sem', 'bucket_mean', 'bucket_median',
#        'bucket_max', 'bucket_min', 'bucket_std', 'bucket_var', 'bucket_sum',
#        'bucket_skew', 'bucket_kurt', 'bucket_mode', 'bucket_ptp', 'bucket_iqr',
#        'bucket_sem', 'final label'],
#       dtype='object')

# %%
y.value_counts()
# Out:
# A    280
# B    132
# Name: final label, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
train = pd.concat([X_train, y_train], axis=1)
test = pd.concat([X_test, y_test], axis=1)

# %%
s = setup(data=data, target="final label", numeric_features=list(X.columns), fix_imbalance=True, 
          feature_selection=True, normalize=True)
# , numeric_features=list(X.drop(columns=["Timestamp"]).columns)
# Out:
# <style type="text/css">
# #T_7c34c_row5_col1, #T_7c34c_row29_col1, #T_7c34c_row44_col1, #T_7c34c_row52_col1, #T_7c34c_row58_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7c34c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c34c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7c34c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c34c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c34c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_7c34c_row0_col1" class="data row0 col1" >440</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c34c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7c34c_row1_col1" class="data row1 col1" >final label</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c34c_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_7c34c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c34c_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_7c34c_row3_col1" class="data row3 col1" >A: 0, B: 1</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c34c_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_7c34c_row4_col1" class="data row4 col1" >(412, 53)</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7c34c_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_7c34c_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7c34c_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_7c34c_row6_col1" class="data row6 col1" >52</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7c34c_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_7c34c_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7c34c_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_7c34c_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7c34c_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_7c34c_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7c34c_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_7c34c_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7c34c_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_7c34c_row11_col1" class="data row11 col1" >(288, 41)</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7c34c_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_7c34c_row12_col1" class="data row12 col1" >(124, 41)</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7c34c_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_7c34c_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7c34c_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_7c34c_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7c34c_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_7c34c_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7c34c_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_7c34c_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7c34c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_7c34c_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7c34c_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_7c34c_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7c34c_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_7c34c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7c34c_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_7c34c_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7c34c_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_7c34c_row21_col1" class="data row21 col1" >3cd3</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_7c34c_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_7c34c_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_7c34c_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_7c34c_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_7c34c_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_7c34c_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_7c34c_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_7c34c_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_7c34c_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_7c34c_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_7c34c_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_7c34c_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_7c34c_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_7c34c_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_7c34c_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_7c34c_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7c34c_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_7c34c_row30_col0

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_ec327 th {
#   text-align: left;
# }
# #T_ec327_row0_col0, #T_ec327_row0_col2, #T_ec327_row1_col0, #T_ec327_row1_col1, #T_ec327_row1_col2, #T_ec327_row1_col3, #T_ec327_row1_col4, #T_ec327_row1_col5, #T_ec327_row1_col6, #T_ec327_row1_col7, #T_ec327_row2_col0, #T_ec327_row2_col1, #T_ec327_row2_col3, #T_ec327_row2_col4, #T_ec327_row2_col5, #T_ec327_row2_col6, #T_ec327_row2_col7, #T_ec327_row3_col0, #T_ec327_row3_col1, #T_ec327_row3_col2, #T_ec327_row3_col3, #T_ec327_row3_col4, #T_ec327_row3_col5, #T_ec327_row3_col6, #T_ec327_row3_col7, #T_ec327_row4_col0, #T_ec327_row4_col1, #T_ec327_row4_col2, #T_ec327_row4_col3, #T_ec327_row4_col4, #T_ec327_row4_col5, #T_ec327_row4_col6, #T_ec327_row4_col7, #T_ec327_row5_col0, #T_ec327_row5_col1, #T_ec327_row5_col2, #T_ec327_row5_col3, #T_ec327_row5_col4, #T_ec327_row5_col5, #T_ec327_row5_col6, #T_ec327_row5_col7, #T_ec327_row6_col0, #T_ec327_row6_col1, #T_ec327_row6_col2, #T_ec327_row6_col3, #T_ec327_row6_col4, #T_ec327_row6_col5, #T_ec327_row6_col6, #T_ec327_row6_col7, #T_ec327_row7_col0, #T_ec327_row7_col1, #T_ec327_row7_col2, #T_ec327_row7_col3, #T_ec327_row7_col4, #T_ec327_row7_col5, #T_ec327_row7_col6, #T_ec327_row7_col7, #T_ec327_row8_col0, #T_ec327_row8_col1, #T_ec327_row8_col2, #T_ec327_row8_col3, #T_ec327_row8_col4, #T_ec327_row8_col5, #T_ec327_row8_col6, #T_ec327_row8_col7, #T_ec327_row9_col0, #T_ec327_row9_col1, #T_ec327_row9_col2, #T_ec327_row9_col3, #T_ec327_row9_col4, #T_ec327_row9_col5, #T_ec327_row9_col6, #T_ec327_row9_col7, #T_ec327_row10_col0, #T_ec327_row10_col1, #T_ec327_row10_col2, #T_ec327_row10_col3, #T_ec327_row10_col4, #T_ec327_row10_col5, #T_ec327_row10_col6, #T_ec327_row10_col7, #T_ec327_row11_col0, #T_ec327_row11_col1, #T_ec327_row11_col2, #T_ec327_row11_col3, #T_ec327_row11_col4, #T_ec327_row11_col5, #T_ec327_row11_col6, #T_ec327_row11_col7, #T_ec327_row12_col0, #T_ec327_row12_col1, #T_ec327_row12_col2, #T_ec327_row12_col3, #T_ec327_row12_col4, #T_ec327_row12_col5, #T_ec327_row12_col6, #T_ec327_row12_col7, #T_ec327_row13_col0, #T_ec327_row13_col1, #T_ec327_row13_col2, #T_ec327_row13_col3, #T_ec327_row13_col4, #T_ec327_row13_col5, #T_ec327_row13_col6, #T_ec327_row13_col7 {
#   text-align: left;
# }
# #T_ec327_row0_col1, #T_ec327_row0_col3, #T_ec327_row0_col4, #T_ec327_row0_col5, #T_ec327_row0_col6, #T_ec327_row0_col7, #T_ec327_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ec327_row0_col8, #T_ec327_row1_col8, #T_ec327_row2_col8, #T_ec327_row3_col8, #T_ec327_row4_col8, #T_ec327_row5_col8, #T_ec327_row6_col8, #T_ec327_row7_col8, #T_ec327_row9_col8, #T_ec327_row11_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ec327_row8_col8, #T_ec327_row10_col8, #T_ec327_row12_col8, #T_ec327_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ec327">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec327_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ec327_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ec327_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ec327_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ec327_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ec327_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ec327_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ec327_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ec327_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec327_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_ec327_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_ec327_row0_col1" class="data row0 col1" >0.9411</td>
#       <td id="T_ec327_row0_col2" class="data row0 col2" >0.9806</td>
#       <td id="T_ec327_row0_col3" class="data row0 col3" >0.9333</td>
#       <td id="T_ec327_row0_col4" class="data row0 col4" >0.9010</td>
#       <td id="T_ec327_row0_col5" class="data row0 col5" >0.9127</td>
#       <td id="T_ec327_row0_col6" class="data row0 col6" >0.8688</td>
#       <td id="T_ec327_row0_col7" class="data row0 col7" >0.8734</td>
#       <td id="T_ec327_row0_col8" class="data row0 col8" >0.0880</td>
#     </tr>
#     <tr>
#       <th id="T_ec327_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_ec327_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ec327_row1_col1" class="data row1 col1" >0.9341</td>
#       <td id="T_ec327_row1_col2" class="data row1 col2" >0.9759</td>
#       <td id="T_ec327_row1_col3" class="data row1 col3" >0.9233</td>
#       <td id="T_ec327_row1_col4" class="data row1 col4" >0.8841</td>
#       <td id="T_ec327_row1_col5" class="data row1 col5" >0.8995</td>
#       <td id="T_ec327_row1_col6" class="data row1 col6" >0.8507</td>
#       <td id="T_ec327_row1_col7" class="data row1 col7" >0.8554</td>
#       <td id="T_ec327_row1_col8" class="data row1 col8" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_ec327_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_ec327_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_ec327_row2_col1" class="data row2 col1" >0.9307</td>
#       <td id="T_ec327_row2_col2" class="data row2 col2" >0.9810</td>
#       <td id="T_ec327_row2_col3" class="data row2 col3" >0.9233</td>
#       <td id="T_ec327_row2_col4" class="data row2 col4" >0.8778</td>
#       <td id="T_ec327_row2_col5" class="data row2 col5" >0.8957</td>
#       <td id="T_ec327_row2_col6" class="data row2 col6" >0.8442</td>
#       <td id="T_ec327_row2_col7" class="data row2 col7" >0.8493</td>
#       <td id="T_ec327_row2_col8" class="data row2 col8" >0.1280</td>
#     </tr>
#     <tr>
#       <th id="T_ec327_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_ec327_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ec327_row3_col1" class="data row3 col1" >0.9234</td>
#       <td id="T_ec327_row3_col2" class="data row3 col2" >0.9782</td>
#       <td id="T_ec327_row3_col3" class="data row3 col3" >0.9111</td>
#       <td id="T_ec327_row3_col4" class="data row3 col4" >0.8707</td>
#       <td id="T_ec327_row3_col5" class="data row3 col5" >0.8833</td>
#       <td id="T_ec327_row3_col6" class="data row3 col6" >0.8267</td>
#       <td id="T_ec327_row3_col7" class="data row3 col7" >0.8341</td>
#       <td id="T_ec327_row3_col8" class="data row3 col8" >0.1360</td>
#     </tr>
#     <tr>
#       <th id="T_ec327_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_ec327_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_ec327_row4_col1" class="data row4 col1" >0.9094</td>
#       <td id="T_ec327_row4_col2" class="data row4 col2" >0.9273</td>
#       <td id="T_ec327_row4_col3" class="data row4 col3" >0.8911</td>
#       <td id="T_ec327_row4_col4" class="data row4 col4" >0.8433</td>
#       <td id="T_ec327_row4_col5" class="data row4 col5" >0.8644</td>
#       <td id="T_ec327_row4_col6" class="data row4 col6" >0.7967</td>
#       <td id="T_ec327_row4_col7" class="data row4 col7" >0.7996</td>
#       <td id="T_ec327_row4_col8" class="data row4 col8" >0.0670</td>
#     </tr>
#     <tr>
#       <th id="T_ec327_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_ec327_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_ec327_row5_col1" class="data row5 col1" >0.8642</td>
#       <td id="T_ec327_row5_col2" class="data row5 col2" >0.9065</td>
#       <td id="T_ec327_row5_col3" class="data row5 col3" >0.8344</td>
#       <td id="T_ec327_row5_col4" class="data row5 col4" >0.7789</td>
#       <td id="T_ec327_row5_col5" class="data row5 col5" >0.7988</td>
#       <td id="T_ec327_row5_col6" class="data row5 col6" >0.6976</td>
#       <td id="T_ec327_row5_col7" class="data row5 col7" >0.7054</td>

# %%
best
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=440, verbose=0,
#                      warm_start=False)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
plot_model(best, plot='feature')

# %%
b = automl(optimize='R2')
b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 b = automl(optimize='R2')
#       2 b
#
# File ~\Anaconda3\envs\machine-learning\lib\site-packages\pycaret\classification.py:2455, in automl(optimize, use_holdout, return_train_score)
#    2410 def automl(
#    2411     optimize: str = "Accuracy",
#    2412     use_holdout: bool = False,
#    2413     return_train_score: bool = False,
#    2414 ) -> Any:
#    2416     """
#    2417     This function returns the best model out of all trained models in
#    2418     current session based on the ``optimize`` parameter. Metrics
#    (...)
#    2453
#    2454     """
# -> 2455     return pycaret.internal.tabular.automl(
#    2456         optimize=optimize,
#    2457         use_holdout=use_holdout,
#    2458         return_train_score=return_train_score,
#    2459     )
#
# File ~\Anaconda3\envs\machine-learning\lib\site-packages\pycaret\internal\tabular.py:9818, in automl(optimize, use_holdout, return_train_score)
#    9816 optimize = _get_metric(optimize)
#    9817 if optimize is None:
# -> 9818     raise ValueError(
#    9819         f"Optimize method not supported. See docstring for list of available parameters."
#    9820     )
#    9822 # checking optimize parameter for multiclass
#    9823 if _is_multiclass():
#
# ValueError: Optimize method not supported. See docstring for list of available parameters.

# %%
predictions = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_21a3c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21a3c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_21a3c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_21a3c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_21a3c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_21a3c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_21a3c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_21a3c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_21a3c_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21a3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21a3c_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_21a3c_row0_col1" class="data row0 col1" >0.8952</td>
#       <td id="T_21a3c_row0_col2" class="data row0 col2" >0.9619</td>
#       <td id="T_21a3c_row0_col3" class="data row0 col3" >0.8000</td>
#       <td id="T_21a3c_row0_col4" class="data row0 col4" >0.8649</td>
#       <td id="T_21a3c_row0_col5" class="data row0 col5" >0.8312</td>
#       <td id="T_21a3c_row0_col6" class="data row0 col6" >0.7553</td>
#       <td id="T_21a3c_row0_col7" class="data row0 col7" >0.7565</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions.to_csv("et_predictions.csv", index=False)

# %%
save_model(best, 'best_model_et')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['ingot_mean',
#                                                            'ingot_median',
#                                                            'ingot_max',
#                                                            'ingot_min',
#                                                            'ingot_std',
#                                                            'ingot_var',
#                                                            'ingot_sum',
#                                                            'ingot_skew',
#                                                            'ingot_kurt',
#                                                            'ingot_mode',
#                                                            'ingot_ptp',
#                                                            'ingot_iqr',
#                                                            'ingot_sem',
#                                                            'mou...
#                   ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                        class_weight=None, criterion='gini',
#                                        max_depth=None, max_features='auto',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=100, n_jobs=-1,
#                                        oob_score=False, random_state=440,
#                                        verbose=0, warm_start=False)]],
#           verbose=False),
#  'best_model_et.pkl')

# %%
model = load_model('./models/20221027/best_model_et')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
from lime.lime_tabular import LimeTabularExplainer
import random
import numpy as np

# %%
# X_train_ = X_train.copy().reset_index(drop=True)
# X_test_ = X_test.copy().reset_index(drop=True)
explainer = LimeTabularExplainer(X_train.values, feature_names=X_train.columns, class_names=['A', 'B'])
i = random.randint(0, X_test.shape[0])
exp = explainer.explain_instance(X_test.iloc[i], model.predict_proba)
exp.show_in_notebook()
# exp.save_to_file("./models/20221026/exp-lgbm.html")
# Out:
# ingot_mean               502.209936
# ingot_median             503.774813
# ingot_max                508.307544
# ingot_min                428.704235
# ingot_std                 10.585227
# ingot_var                112.047026
# ingot_sum              48212.153840
# ingot_skew                -6.374980
# ingot_kurt                41.606657
# ingot_mode               434.637564
# ingot_ptp                 79.603310
# ingot_iqr                  3.395312
# ingot_sem                  1.080350
# mould_mean               317.857150
# mould_median             317.881155
# mould_max                328.469858
# mould_min                315.206098
# mould_std                  1.171634
# mould_var                  1.372727
# mould_sum              41639.286646
# mould_skew                 5.595401
# mould_kurt                51.664576
# mould_mode               317.842453
# mould_ptp                 13.263759
# mould_iqr                  0.975678
# mould_sem                  0.102366
# oil_pressure_mean        430.064699
# oil_pressure_median      430.377274
# oil_pressure_max         430.901142
# oil_pressure_min         425.877456
# oil_pressure_std           0.714077
# oil_pressure_var           0.509906
# oil_pressure_sum       56338.475628
# oil_pressure_skew         -2.179455
# oil_pressure_kurt          9.369959
# oil_pressure_mode        430.533144
# oil_pressure_ptp           5.023686
# oil_pressure_iqr           1.048932
# oil_pressure_sem           0.062389
# bucket_mean              567.718268
# bucket_median            573.571686
# bucket_max               578.813130
# bucket_min               521.223299
# bucket_std                14.840772
# bucket_var               220.248519
# bucket_sum             74371.093064
# bucket_skew               -2.247365
# bucket_kurt                3.577934
# bucket_mode              522.309854
# bucket_ptp                57.589831
# bucket_iqr                 4.095913
# bucket_sem                 1.296644
# Name: 384, dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [58], line 6
#       4 i = random.randint(0, X_test.shape[0])
#       5 print(X_test.iloc[i])
# ----> 6 exp = explainer.explain_instance(np.array(X_test.iloc[i]), model.predict_proba)
#       7 exp.show_in_notebook()
#
# File ~\Anaconda3\envs\pycaret\lib\site-packages\lime\lime_tabular.py:340, in LimeTabularExplainer.explain_instance(self, data_row, predict_fn, labels, top_labels, num_features, num_samples, distance_metric, model_regressor)
#     337 if sp.sparse.issparse(data_row) and not sp.sparse.isspmatrix_csr(data_row):
#     338     # Preventative code: if sparse, convert to csr format if not in csr format already
#     339     data_row = data_row.tocsr()
# --> 340 data, inverse = self.__data_inverse(data_row, num_samples)
#     341 if sp.sparse.issparse(data):
#     342     # Note in sparse case we don't subtract mean since data would become dense
#     343     scaled_data = data.multiply(self.scaler.scale_)
#
# File ~\Anaconda3\envs\pycaret\lib\site-packages\lime\lime_tabular.py:550, in LimeTabularExplainer.__data_inverse(self, data_row, num_samples)
#     548     inverse[:, column] = inverse_column
#     549 if self.discretizer is not None:
# --> 550     inverse[1:] = self.discretizer.undiscretize(inverse[1:])
#     551 inverse[0] = data_row
#     552 return data, inverse
#
# File ~\Anaconda3\envs\pycaret\lib\site-packages\lime\discretize.py:144, in BaseDiscretizer.undiscretize(self, data)
#     140         ret[feature] = self.get_undiscretize_values(
#     141             feature, ret[feature].astype(int).reshape(-1, 1)
#     142         )
#     143     else:
# --> 144         ret[:, feature] = self.get_undiscretize_values(
#     145             feature, ret[:, feature].astype(int)
#     146         )
#     147 return ret
#
# File ~\Anaconda3\envs\pycaret\lib\site-packages\lime\discretize.py:127, in BaseDiscretizer.get_undiscretize_values(self, feature, values)
#     124 min_max_unequal = (minz != maxz)
#     126 ret = minz
# --> 127 ret[np.where(min_max_unequal)] = scipy.stats.truncnorm.rvs(
#     128     minz[min_max_unequal],
#     129     maxz[min_max_unequal],
#     130     loc=means[min_max_unequal],
#     131     scale=stds[min_max_unequal],
#     132     random_state=self.random_state
#     133 )
#     134 return ret
#
# File ~\Anaconda3\envs\pycaret\lib\site-packages\scipy\stats\_distn_infrastructure.py:979, in rv_generic.rvs(self, *args, **kwds)
#     977 cond = logical_and(self._argcheck(*args), (scale >= 0))
#     978 if not np.all(cond):
# --> 979     raise ValueError("Domain error in arguments.")
#     981 if np.all(scale == 0):
#     982     return loc*ones(size, 'd')
#
# ValueError: Domain error in arguments.
